# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
dates = pd.date_range('20170101', periods=10)
dates
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(10,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2017-01-01 -1.443411 -1.183238  1.290925  0.487981
# 2017-01-02 -1.493927  1.075288 -0.672653  1.411594
# 2017-01-03 -0.204179  1.975606 -0.600809 -0.005032
# 2017-01-04 -1.457045  0.588652  0.417706  1.144870
# 2017-01-05 -0.469661 -0.091325  1.294331  0.191847
# 2017-01-06 -0.101655 -1.195250  1.418805 -0.290260
# 2017-01-07  1.284894  0.596155  0.708839 -0.526712
# 2017-01-08  1.819033 -0.271844  0.767729  1.073522
# 2017-01-09 -0.094897  0.083601  0.575080  1.103231
# 2017-01-10  0.189660 -1.259683 -1.247625 -1.668936

# %%
df.plot()
